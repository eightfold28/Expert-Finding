# %%
def create_n_gram_keyword(arr, n):
    keywords = []
    if len(arr) > 1:
        for i in range(0, len(arr) - n + 1):
            temp = ''
            for j in range (i, i+n):
                temp = temp + " " + arr[j]
            keywords.append(temp.strip())
        return keywords
    else:
        return arr

# %%
import csv

all_keywords = dict()
with open('keyword_keahlian.csv') as csv_file:
    reader = csv.DictReader(csv_file)
    for row in reader:
        keywords = row['key'].split(", ")
        label = row['value']
        for keyword in keywords:
            if keyword in all_keywords:
                all_keywords[keyword.lower()].append(label)
            else:
                all_keywords[keyword.lower()] = [label]

# %%
mata_kuliah_keahlian = dict()
field = ['id', 'nama_matakuliah', 'keahlian_id']
f = open('output.csv', 'w')

with open('caripakar_app_matakuliah.csv') as csv_file:
    reader = csv.DictReader(csv_file)
    writer = csv.DictWriter(f, fieldnames= field)
    writer.writeheader()
    for row in reader:
        matkul = row['nama_matakuliah'].lower()
        total_keyword = 0 # total keyword in one title
        count_keyword = dict()

        temp_keywords = dict()
        print ("=======" + matkul + "=========")
        matkul_keywords = matkul.split(" ") # list matkul per kata
        
        for gram in range(1, 4):
            gram_keywords = create_n_gram_keyword(matkul_keywords, gram) # make array of 1-4 gram keywords
            for keyword in gram_keywords:
                if keyword in all_keywords:
                    value_keyword = all_keywords[keyword]
                    temp_keywords[keyword] = value_keyword
                    for value in all_keywords[keyword]:
                        if value in count_keyword:
                            count_keyword[value] += 1
                        else:
                            count_keyword[value] = 1
                else:
                    temp_keywords[keyword] = None
        
        keys = temp_keywords.keys()
        for key in keys:
            if temp_keywords[key] is not None:
                for k in temp_keywords[key]:
                    print(key + ' -> ' + k)
                    total_keyword += 1
        print("total keyword:", total_keyword)
        print(count_keyword) 
        if total_keyword > 0:
            print("klasifikasi keahlian: " + max(count_keyword.keys(), key=lambda k: count_keyword[k]))
            print("ada")
            new_row = {'id': row['id'], 'nama_matakuliah': row['nama_matakuliah'], 'keahlian_id': max(count_keyword.keys(), key=lambda k: count_keyword[k])}
        else:
            new_row = {'id': row['id'], 'nama_matakuliah': row['nama_matakuliah'], 'keahlian_id': 'NULL'}
        if (writer.writerow(new_row)):
            print ("done")
f.close()
csv_file.close()
# Out:
# =======sistem operasi=========
# sistem -> 3
# sistem -> 4
# sistem operasi -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======jaringan komputer & pengamanannya=========
# jaringan -> 3
# jaringan komputer -> 3
# total keyword: 2
# {'3': 2}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem terdistribusi=========
# sistem -> 3
# sistem -> 4
# terdistribusi -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======jaringan komputer=========
# jaringan -> 3
# jaringan komputer -> 3
# total keyword: 2
# {'3': 2}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem komputer=========
# sistem -> 3
# sistem -> 4
# sistem komputer -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======pemrosesan dan manajemen data multimedia=========
# manajemen -> 4
# data -> 4
# total keyword: 2
# {'4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======project management=========
# project -> 5
# management -> 5
# total keyword: 2
# {'5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======tesis=========
# total keyword: 0
# {}
# done
# =======sistem arsitekturkomputer a=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem operasi lanjut=========
# sistem -> 3
# sistem -> 4
# sistem operasi -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem paralel dan terdistribusi=========
# sistem -> 3
# sistem -> 4
# paralel -> 3
# terdistribusi -> 3
# total keyword: 4
# {'3': 3, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem & arsitektur komputer a=========
# sistem -> 3
# sistem -> 4
# arsitektur -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======tesis i=========
# total keyword: 0
# {}
# done
# =======pemodelan berorientasi obyek & rek. per.=========
# pemodelan -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======basis data multimedia=========
# data -> 4
# basis data -> 4
# total keyword: 2
# {'4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======perancangan perangkat lunak=========
# perangkat lunak -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======bisnis secara elektronik=========
# total keyword: 0
# {}
# done
# =======rangkaian logika teknik digital=========
# rangkaian -> 10
# logika -> 2
# logika -> 7
# total keyword: 3
# {'10': 1, '2': 1, '7': 1}
# klasifikasi keahlian: 10
# ada
# done
# =======interaksi komputer-manusia=========
# interaksi -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======sistem multimedia=========
# sistem -> 3
# sistem -> 4
# sistem multimedia -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======tesis ii=========
# total keyword: 0
# {}
# done
# =======rangkaian logika & teknik digital=========
# rangkaian -> 10
# logika -> 2
# logika -> 7
# total keyword: 3
# {'10': 1, '2': 1, '7': 1}
# klasifikasi keahlian: 10
# ada
# done
# =======manajemen proyek teknologi informasi=========
# manajemen -> 4
# proyek -> 5
# informasi -> 4
# manajemen proyek -> 5
# total keyword: 4
# {'4': 2, '5': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======pengembangan aplikasi berorientasi objek=========
# pengembangan aplikasi -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======pemrograman paralel=========
# pemrograman -> 1
# paralel -> 3
# total keyword: 2
# {'1': 1, '3': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======rekayasa perangkat lunak lanjut=========
# perangkat lunak -> 5
# rekayasa perangkat lunak -> 5
# total keyword: 2
# {'5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======sistem digital=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem probabilistik dan stokastik=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======matematika teknik i=========
# matematika -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======agama dan etika katolik=========
# total keyword: 0
# {}
# done
# =======pengenalan teknologi informasi a=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======pancasila dan kewarganegaraan=========
# total keyword: 0
# {}
# done
# =======pemahaman teks akademik=========
# total keyword: 0
# {}
# done
# =======tata tulis karya ilmiah=========
# total keyword: 0
# {}
# done
# =======fisika dasar iia=========
# total keyword: 0
# {}
# done
# =======ekonomi teknik=========
# total keyword: 0
# {}
# done
# =======agama dan etika protestan=========
# total keyword: 0
# {}
# done
# =======olah raga=========
# total keyword: 0
# {}
# done
# =======agama dan etika budha=========
# total keyword: 0
# {}
# done
# =======etika hukum cyber=========
# total keyword: 0
# {}
# done
# =======manajemen data=========
# manajemen -> 4
# data -> 4
# total keyword: 2
# {'4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======teknik presentasi=========
# total keyword: 0
# {}
# done
# =======rekayasa interaksi=========
# interaksi -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======kalkulus ia=========
# kalkulus -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======komposisi=========
# total keyword: 0
# {}
# done
# =======tugas akhir i  seminar=========
# total keyword: 0
# {}
# done
# =======sistem alam semesta=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======praktikum sistem digital=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======rekayasa perangkat lunak=========
# perangkat lunak -> 5
# rekayasa perangkat lunak -> 5
# total keyword: 2
# {'5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======jaringan informasi=========
# jaringan -> 3
# informasi -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======manajemen keekonomian proyek=========
# manajemen -> 4
# proyek -> 5
# total keyword: 2
# {'4': 1, '5': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======politik dan tata pemerintahan=========
# total keyword: 0
# {}
# done
# =======elektronika i=========
# total keyword: 0
# {}
# done
# =======manajemen insani kontemporer=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======struktur diskrit=========
# diskrit -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======pengembangan organisasi dan organisasi p=========
# total keyword: 0
# {}
# done
# =======celup ikat=========
# total keyword: 0
# {}
# done
# =======bisnis secaraelektronik=========
# total keyword: 0
# {}
# done
# =======perancangan arsitektur enterprise=========
# arsitektur -> 3
# enterprise -> 9
# arsitektur enterprise -> 9
# total keyword: 3
# {'3': 1, '9': 2}
# klasifikasi keahlian: 9
# ada
# done
# =======perencanaanstrategis teknologi inf=========
# total keyword: 0
# {}
# done
# =======kapita selekta sti=========
# total keyword: 0
# {}
# done
# =======sistem arsitekturkomputer b=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======pengetahuanlingkungan=========
# total keyword: 0
# {}
# done
# =======hukum etikateknologi informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======keamanan informasi=========
# keamanan -> 4
# keamanan -> 8
# informasi -> 4
# keamanan informasi -> 3
# keamanan informasi -> 3
# keamanan informasi -> 5
# total keyword: 6
# {'4': 2, '8': 1, '3': 2, '5': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======dasar pemrograman=========
# pemrograman -> 1
# dasar pemrograman -> 1
# total keyword: 2
# {'1': 2}
# klasifikasi keahlian: 1
# ada
# done
# =======sosiologi komunikasi=========
# total keyword: 0
# {}
# done
# =======pengantar analisis rangkaian=========
# analisis -> 2
# rangkaian -> 10
# total keyword: 2
# {'2': 1, '10': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======manajemem pengembangan aplikasi=========
# pengembangan aplikasi -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======komunikasi merek=========
# total keyword: 0
# {}
# done
# =======pemrosesan bahasa alami dan ucapan=========
# bahasa alami -> 7
# pemrosesan bahasa alami -> 7
# total keyword: 2
# {'7': 2}
# klasifikasi keahlian: 7
# ada
# done
# =======visualisasi data dan informasi=========
# visualisasi -> 6
# visualisasi -> 6
# data -> 4
# informasi -> 4
# visualisasi data -> 4
# total keyword: 5
# {'6': 2, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======manajemen pengembangan aplikasi=========
# manajemen -> 4
# pengembangan aplikasi -> 1
# total keyword: 2
# {'4': 1, '1': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======manajemen informasi b=========
# manajemen -> 4
# informasi -> 4
# manajemen informasi -> 4
# total keyword: 3
# {'4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======pemrograman lanjut=========
# pemrograman -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======teknologi basis data=========
# data -> 4
# basis data -> 4
# teknologi basis data -> 4
# total keyword: 3
# {'4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======studi mandiri ii=========
# total keyword: 0
# {}
# done
# =======manajemen informasi a=========
# manajemen -> 4
# informasi -> 4
# manajemen informasi -> 4
# total keyword: 3
# {'4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======topik khusus ii=========
# total keyword: 0
# {}
# done
# =======teori basis data=========
# data -> 4
# basis data -> 4
# total keyword: 2
# {'4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======studi mandiri i=========
# total keyword: 0
# {}
# done
# =======manajemen resiko enterprise=========
# manajemen -> 4
# enterprise -> 9
# total keyword: 2
# {'4': 1, '9': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======metodologipenelitian/tesis 1=========
# total keyword: 0
# {}
# done
# =======sistem basis data=========
# sistem -> 3
# sistem -> 4
# data -> 4
# basis data -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======sistem basis data terdistribusi=========
# sistem -> 3
# sistem -> 4
# data -> 4
# terdistribusi -> 3
# basis data -> 4
# total keyword: 5
# {'3': 2, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======basis data nonrelasional=========
# data -> 4
# basis data -> 4
# total keyword: 2
# {'4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======basis data=========
# data -> 4
# basis data -> 4
# total keyword: 2
# {'4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======konsep pengembangan ilmu pengetahuan=========
# pengetahuan -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======pemodelan basis data=========
# pemodelan -> 2
# data -> 4
# basis data -> 4
# total keyword: 3
# {'2': 1, '4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======manajemen informasia=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======pengantar rekayasa & desain ii=========
# desain -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======sistem alam & semesta=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======evolusi perangkatlunak=========
# total keyword: 0
# {}
# done
# =======topik khusus rekayasa perangkat lunak=========
# perangkat lunak -> 5
# rekayasa perangkat lunak -> 5
# total keyword: 2
# {'5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======pemrograman komputer (tm)=========
# pemrograman -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======rekayasa kebutuhan sistem perangkat lu=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======strategi & kebijakan=========
# total keyword: 0
# {}
# done
# =======algoritma struktur data=========
# algoritma -> 1
# data -> 4
# struktur data -> 1
# total keyword: 3
# {'1': 2, '4': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======kualitas perangkat lunak=========
# perangkat lunak -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======rekayasa kebutuhansistem  perangkat=========
# total keyword: 0
# {}
# done
# =======secure softwaredevelopmentlife cycle=========
# total keyword: 0
# {}
# done
# =======pengenalan teknologi informasi b=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======metoda & proses pembangunan perangkat lu=========
# total keyword: 0
# {}
# done
# =======dasar rekayasa perangkat lunak=========
# perangkat lunak -> 5
# rekayasa perangkat lunak -> 5
# total keyword: 2
# {'5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======sinyal sistem=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem kendali non linier=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======probabilitas statistik=========
# probabilitas -> 2
# probabilitas -> 7
# total keyword: 2
# {'2': 1, '7': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======sinyal & sistem=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======probabilitas & statistik=========
# probabilitas -> 2
# probabilitas -> 7
# total keyword: 2
# {'2': 1, '7': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======probabilitas statistika=========
# probabilitas -> 2
# probabilitas -> 7
# statistika -> 2
# statistika -> 7
# total keyword: 4
# {'2': 2, '7': 2}
# klasifikasi keahlian: 2
# ada
# done
# =======pengolahan sinyal digital=========
# total keyword: 0
# {}
# done
# =======rekayasa perangkat teknologi informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======strategi dan sistem pemerintahan=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem kendali nonlinear=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======probabilitas danstatistik=========
# probabilitas -> 2
# probabilitas -> 7
# total keyword: 2
# {'2': 1, '7': 1}
# klasifikasi keahlian: 2
# ada
# done
# ================
# total keyword: 0
# {}
# done
# =======tugas akhir ii=========
# total keyword: 0
# {}
# done
# =======tugas akhir i & seminar=========
# total keyword: 0
# {}
# done
# =======sumber daya informasi enterprise=========
# informasi -> 4
# enterprise -> 9
# total keyword: 2
# {'4': 1, '9': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======pemrograman berorientasi objek=========
# pemrograman -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======sosioteknologiinformasi=========
# total keyword: 0
# {}
# done
# =======pemrograman fungsional=========
# pemrograman -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======algoritma strukturdata=========
# algoritma -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======pemodelan data lanjut=========
# pemodelan -> 2
# data -> 4
# pemodelan data -> 4
# pemodelan data lanjut -> 4
# total keyword: 4
# {'2': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======penulisan karya ilmiah=========
# total keyword: 0
# {}
# done
# =======topik khusus=========
# total keyword: 0
# {}
# done
# =======fundamentalintelijen bisnis=========
# total keyword: 0
# {}
# done
# =======topik khusus sains komputer 2=========
# total keyword: 0
# {}
# done
# =======visualisasi data=========
# visualisasi -> 6
# visualisasi -> 6
# data -> 4
# visualisasi data -> 4
# total keyword: 4
# {'6': 2, '4': 2}
# klasifikasi keahlian: 6
# ada
# done
# =======komunikasi antar personal=========
# total keyword: 0
# {}
# done
# =======rekayasasistem kerja=========
# total keyword: 0
# {}
# done
# =======pemasaran jasa=========
# total keyword: 0
# {}
# done
# =======desianinteraksi,visualisasi dan game=========
# game -> 6
# total keyword: 1
# {'6': 1}
# klasifikasi keahlian: 6
# ada
# done
# =======agama dan etika hindu=========
# total keyword: 0
# {}
# done
# =======kerja praktek=========
# total keyword: 0
# {}
# done
# =======teknologi dan manajemen operasi=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======statistika bisnis=========
# statistika -> 2
# statistika -> 7
# total keyword: 2
# {'2': 1, '7': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======anatomi fisiologi praktikum=========
# total keyword: 0
# {}
# done
# =======inteligensi kolektif=========
# total keyword: 0
# {}
# done
# =======perancangan sistem interaksi=========
# sistem -> 3
# sistem -> 4
# interaksi -> 5
# total keyword: 3
# {'3': 1, '4': 1, '5': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem informasi kesehatan=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======keamanan informasi lanjut=========
# keamanan -> 4
# keamanan -> 8
# informasi -> 4
# keamanan informasi -> 3
# keamanan informasi -> 3
# keamanan informasi -> 5
# total keyword: 6
# {'4': 2, '8': 1, '3': 2, '5': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======pengujian perangkat lunak=========
# perangkat lunak -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======pengantar kepariwisataan=========
# total keyword: 0
# {}
# done
# =======analisa kuantitatif kualitatif=========
# total keyword: 0
# {}
# done
# =======teknik biomedika praktikum=========
# total keyword: 0
# {}
# done
# =======manajemen teknologi=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======kepemimpinan bisnis=========
# total keyword: 0
# {}
# done
# =======metoda penelitian=========
# total keyword: 0
# {}
# done
# =======kerekayasaan informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======metode formal=========
# total keyword: 0
# {}
# done
# =======data management=========
# data -> 4
# management -> 5
# total keyword: 2
# {'4': 1, '5': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======pengembangankeprofesian/komunitasa=========
# total keyword: 0
# {}
# done
# =======pengetahuan dan inovasi=========
# pengetahuan -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======pembelajaran mesin=========
# mesin -> 7
# pembelajaran mesin -> 7
# pembelajaran mesin -> 7
# total keyword: 3
# {'7': 3}
# klasifikasi keahlian: 7
# ada
# done
# =======algoritma & pemrograman b=========
# algoritma -> 1
# pemrograman -> 1
# total keyword: 2
# {'1': 2}
# klasifikasi keahlian: 1
# ada
# done
# =======keamanan sistem  perangkat lunak=========
# keamanan -> 4
# keamanan -> 8
# sistem -> 3
# sistem -> 4
# perangkat lunak -> 5
# total keyword: 5
# {'4': 3, '8': 1, '3': 2, '5': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======datawarehouse datamining=========
# total keyword: 0
# {}
# done
# =======manajemen sistem informasi=========
# manajemen -> 4
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 5
# {'4': 4, '3': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======keamanan perangkat lunak=========
# keamanan -> 4
# keamanan -> 8
# perangkat lunak -> 5
# total keyword: 3
# {'4': 1, '8': 1, '5': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======pembelajaran mesin lanjut=========
# mesin -> 7
# pembelajaran mesin -> 7
# pembelajaran mesin -> 7
# total keyword: 3
# {'7': 3}
# klasifikasi keahlian: 7
# ada
# done
# =======data warehouse & business intelligence=========
# data -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======pengembangan intelijen bisnis & operas=========
# total keyword: 0
# {}
# done
# =======representasi & penalaran pengetahuan=========
# penalaran -> 7
# pengetahuan -> 7
# total keyword: 2
# {'7': 2}
# klasifikasi keahlian: 7
# ada
# done
# =======jaringan multilayanan & jaringan multime=========
# jaringan -> 3
# total keyword: 1
# {'3': 2}
# klasifikasi keahlian: 3
# ada
# done
# =======mikroelektronika frekuensi radio=========
# total keyword: 0
# {}
# done
# =======kewirausahaan teknologi informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======matematika informatik=========
# matematika -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======manajemen resiko=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======otomata & teori bahasa formal=========
# total keyword: 0
# {}
# done
# =======strategi & kebijakan tek. informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======algoritma kombinatorial=========
# algoritma -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======probabilitas & statistika=========
# probabilitas -> 2
# probabilitas -> 7
# statistika -> 2
# statistika -> 7
# total keyword: 4
# {'2': 2, '7': 2}
# klasifikasi keahlian: 2
# ada
# done
# =======matematika diskrit=========
# matematika -> 2
# diskrit -> 2
# matematika diskrit -> 2
# total keyword: 3
# {'2': 3}
# klasifikasi keahlian: 2
# ada
# done
# =======sistim berkas dan basis data=========
# data -> 4
# basis data -> 4
# total keyword: 2
# {'4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======manajemen resiko sistem informasi=========
# manajemen -> 4
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 5
# {'4': 4, '3': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======teori bahasa dan otomata=========
# total keyword: 0
# {}
# done
# =======probabilitas  statistika=========
# probabilitas -> 2
# probabilitas -> 7
# statistika -> 2
# statistika -> 7
# total keyword: 4
# {'2': 4, '7': 4}
# klasifikasi keahlian: 2
# ada
# done
# =======tugas akhir 2=========
# total keyword: 0
# {}
# done
# =======tugas akhir 1 & seminar=========
# total keyword: 0
# {}
# done
# =======metode numerik lanjut=========
# total keyword: 0
# {}
# done
# =======teori bahasa formal dan otomata=========
# total keyword: 0
# {}
# done
# =======manajemen sumber daya sti=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======pemrogramanintegratif=========
# total keyword: 0
# {}
# done
# =======matematika sti=========
# matematika -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======instrumentasi sistem kendali=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======rekayasa sistem multimedia=========
# sistem -> 3
# sistem -> 4
# sistem multimedia -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======grafika komputer=========
# grafika -> 6
# grafika komputer -> 6
# total keyword: 2
# {'6': 2}
# klasifikasi keahlian: 6
# ada
# done
# =======interpretasi & pengolahan citra=========
# citra -> 6
# total keyword: 1
# {'6': 1}
# klasifikasi keahlian: 6
# ada
# done
# =======sistem grafika komputer=========
# sistem -> 3
# sistem -> 4
# grafika -> 6
# grafika komputer -> 6
# total keyword: 4
# {'3': 1, '4': 1, '6': 2}
# klasifikasi keahlian: 6
# ada
# done
# =======sistem intelijen terapan=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem intelijen=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======grafika komputer terapan=========
# grafika -> 6
# grafika komputer -> 6
# total keyword: 2
# {'6': 2}
# klasifikasi keahlian: 6
# ada
# done
# =======fundamental inteligensi buatan=========
# total keyword: 0
# {}
# done
# =======metode numerik=========
# total keyword: 0
# {}
# done
# =======grafika komputer visualisasi=========
# grafika -> 6
# visualisasi -> 6
# visualisasi -> 6
# grafika komputer -> 6
# total keyword: 4
# {'6': 4}
# klasifikasi keahlian: 6
# ada
# done
# =======pemodelan & simulasi=========
# pemodelan -> 2
# simulasi -> 2
# total keyword: 2
# {'2': 2}
# klasifikasi keahlian: 2
# ada
# done
# =======pemodelan informasi=========
# pemodelan -> 2
# informasi -> 4
# total keyword: 2
# {'2': 1, '4': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======topik khusus sainskomputer ii=========
# total keyword: 0
# {}
# done
# =======sistem rekognisi=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======kapita selekta=========
# total keyword: 0
# {}
# done
# =======pengenalan pola=========
# total keyword: 0
# {}
# done
# =======interpretasi dan pengolahan citra=========
# citra -> 6
# total keyword: 1
# {'6': 1}
# klasifikasi keahlian: 6
# ada
# done
# =======teknologi multimedia=========
# total keyword: 0
# {}
# done
# =======strategi dan pengembangan ti=========
# total keyword: 0
# {}
# done
# =======perencanaan strategis teknologi informas=========
# total keyword: 0
# {}
# done
# =======teori manajemen & organisasi=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======arsitektur berbasis layanan=========
# arsitektur -> 3
# layanan -> 5
# total keyword: 2
# {'3': 1, '5': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======perancangan aplikasi berbasislayanan=========
# total keyword: 0
# {}
# done
# =======tata kelola  pengukurankinerja tekno=========
# total keyword: 0
# {}
# done
# =======manajemen resiko teknologi informasi=========
# manajemen -> 4
# informasi -> 4
# total keyword: 2
# {'4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======sistem komputasi=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======rekayasa perangkat lunak untuk domain game=========
# game -> 6
# perangkat lunak -> 5
# rekayasa perangkat lunak -> 5
# total keyword: 3
# {'6': 1, '5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======it ethics,regulation & cyber law=========
# total keyword: 0
# {}
# done
# =======pemodelan dan simulasi=========
# pemodelan -> 2
# simulasi -> 2
# pemodelan dan simulasi -> 2
# total keyword: 3
# {'2': 3}
# klasifikasi keahlian: 2
# ada
# done
# =======aljabar geometri=========
# geometri -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======teori komputasi=========
# total keyword: 0
# {}
# done
# =======organisasi sistem komputer=========
# sistem -> 3
# sistem -> 4
# sistem komputer -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======information distribution=========
# total keyword: 0
# {}
# done
# =======pengenalan informatika=========
# total keyword: 0
# {}
# done
# =======rekayasa perangkat lunak dasar=========
# perangkat lunak -> 5
# rekayasa perangkat lunak -> 5
# total keyword: 2
# {'5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======jaringan komputer lanjut=========
# jaringan -> 3
# jaringan komputer -> 3
# jaringan komputer lanjut -> 3
# total keyword: 3
# {'3': 3}
# klasifikasi keahlian: 3
# ada
# done
# =======electronic business=========
# total keyword: 0
# {}
# done
# =======teknologi sistem komputer=========
# sistem -> 3
# sistem -> 4
# sistem komputer -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======e-bisnis=========
# total keyword: 0
# {}
# done
# =======keamanan komputer=========
# keamanan -> 4
# keamanan -> 8
# total keyword: 2
# {'4': 1, '8': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======perawatan perangkat lunak=========
# perangkat lunak -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======sistem berbasis komponen=========
# sistem -> 3
# sistem -> 4
# komponen -> 5
# total keyword: 3
# {'3': 1, '4': 1, '5': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem informasi dan e-commerce=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======mnj. proyek teknologi informasi=========
# proyek -> 5
# informasi -> 4
# total keyword: 2
# {'5': 1, '4': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======pengantar aplikasi komputer=========
# total keyword: 0
# {}
# done
# =======metode penelitian=========
# total keyword: 0
# {}
# done
# =======pembangunan perangkat lunak=========
# perangkat lunak -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======keamanan sistem informasi=========
# keamanan -> 4
# keamanan -> 8
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 6
# {'4': 4, '8': 1, '3': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======praktik audit=========
# total keyword: 0
# {}
# done
# =======konsep teknologi=========
# total keyword: 0
# {}
# done
# =======komputer grafik=========
# grafik -> 6
# total keyword: 1
# {'6': 1}
# klasifikasi keahlian: 6
# ada
# done
# =======metode berpikirkreatif=========
# total keyword: 0
# {}
# done
# =======kriptografi=========
# kriptografi -> 2
# total keyword: 1
# {'2': 3}
# klasifikasi keahlian: 2
# ada
# done
# =======komunikasipembangunan=========
# total keyword: 0
# {}
# done
# =======analisis perangkat lunak=========
# analisis -> 2
# perangkat lunak -> 5
# total keyword: 2
# {'2': 1, '5': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======agama dan etika islam=========
# total keyword: 0
# {}
# done
# =======kewirausahaan=========
# total keyword: 0
# {}
# done
# =======pengantar bioinformatik=========
# total keyword: 0
# {}
# done
# =======fotografi dasar=========
# total keyword: 0
# {}
# done
# =======rekayasa lingkungan=========
# total keyword: 0
# {}
# done
# =======manajemen sdm=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======dasar rangkaian elektrik=========
# rangkaian -> 10
# total keyword: 1
# {'10': 1}
# klasifikasi keahlian: 10
# ada
# done
# =======kalkulus iia=========
# kalkulus -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======sosiologi industri=========
# total keyword: 0
# {}
# done
# =======tinjauan arsitektur dan interior=========
# arsitektur -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======berpikir visioner=========
# total keyword: 0
# {}
# done
# =======kewirausahaan & pengembangan enterprais=========
# total keyword: 0
# {}
# done
# =======matematika rekayasa=========
# matematika -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======pengantar ekonomika=========
# total keyword: 0
# {}
# done
# =======penulisan naskahiklan=========
# total keyword: 0
# {}
# done
# =======algoritma dan pemrograman=========
# algoritma -> 1
# pemrograman -> 1
# total keyword: 2
# {'1': 2}
# klasifikasi keahlian: 1
# ada
# done
# =======metodologi amdal=========
# metodologi -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======pemodelan matematika=========
# pemodelan -> 2
# matematika -> 2
# total keyword: 2
# {'2': 2}
# klasifikasi keahlian: 2
# ada
# done
# =======tipografi dasar=========
# total keyword: 0
# {}
# done
# =======organisasi danmanajemen perusahaanin=========
# total keyword: 0
# {}
# done
# =======psikologi persepsi=========
# total keyword: 0
# {}
# done
# =======perancangan e-bisnis=========
# total keyword: 0
# {}
# done
# =======manajemen (ii)=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======manajemen rekayasaindustri=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======portofolio=========
# total keyword: 0
# {}
# done
# =======sistem informasi manajemenuas=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======communication and networking=========
# total keyword: 0
# {}
# done
# =======software engineering=========
# total keyword: 0
# {}
# done
# =======rekayasa perangkat lunak berbasis kompon=========
# perangkat lunak -> 5
# rekayasa perangkat lunak -> 5
# total keyword: 2
# {'5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======0=========
# total keyword: 0
# {}
# done
# =======intelligent bisnis=========
# total keyword: 0
# {}
# done
# =======analisis, perancangan berorientasi objek=========
# total keyword: 0
# {}
# done
# =======rekayasa sistem informasi=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======jaringan komputer dan komunikasi data=========
# jaringan -> 3
# data -> 4
# jaringan komputer -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======perencanaan strategis sistem informasi=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======perancangan perangkat lunak si=========
# perangkat lunak -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======analisis perancanganberorientasi obj=========
# analisis -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======sistem penunjang keputusan dan sis pakar=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======manajemen proyek dan perubahan=========
# manajemen -> 4
# proyek -> 5
# manajemen proyek -> 5
# total keyword: 3
# {'4': 1, '5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======manajemen proyekperangkat lunak=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======rekayasa perangkat lunak i=========
# perangkat lunak -> 5
# rekayasa perangkat lunak -> 5
# total keyword: 2
# {'5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======analisis data & bisnis=========
# analisis -> 2
# data -> 4
# total keyword: 2
# {'2': 1, '4': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======manajemen rekayasaperangkat lunak=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======keamanan sistem & perangkat lunak=========
# keamanan -> 4
# keamanan -> 8
# sistem -> 3
# sistem -> 4
# perangkat lunak -> 5
# total keyword: 5
# {'4': 2, '8': 1, '3': 1, '5': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======technopreneurship=========
# total keyword: 0
# {}
# done
# =======rekayasa perangkat lunak ii=========
# perangkat lunak -> 5
# rekayasa perangkat lunak -> 5
# total keyword: 2
# {'5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======perenc. strategis sistem informasi=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======manajemen kualitas perangkat lunak=========
# manajemen -> 4
# perangkat lunak -> 5
# total keyword: 2
# {'4': 1, '5': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======sistem informasi manajemen=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# manajemen -> 4
# sistem informasi -> 4
# total keyword: 5
# {'3': 1, '4': 4}
# klasifikasi keahlian: 4
# ada
# done
# =======proyek perangkat lunak=========
# proyek -> 5
# perangkat lunak -> 5
# proyek perangkat lunak -> 5
# total keyword: 3
# {'5': 3}
# klasifikasi keahlian: 5
# ada
# done
# =======elektronika daya=========
# total keyword: 0
# {}
# done
# =======rangkaian elektrik=========
# rangkaian -> 10
# total keyword: 1
# {'10': 1}
# klasifikasi keahlian: 10
# ada
# done
# =======kendali mesin elektrik=========
# mesin -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======pra tesis=========
# total keyword: 0
# {}
# done
# =======teknik tenaga elektrik (msmg)=========
# total keyword: 0
# {}
# done
# =======dasar pemrograman berorientasi obyek=========
# pemrograman -> 1
# dasar pemrograman -> 1
# total keyword: 2
# {'1': 2}
# klasifikasi keahlian: 1
# ada
# done
# =======pemrograman web=========
# pemrograman -> 1
# web -> 1
# total keyword: 2
# {'1': 2}
# klasifikasi keahlian: 1
# ada
# done
# =======pemrograman sistem=========
# pemrograman -> 1
# sistem -> 3
# sistem -> 4
# total keyword: 3
# {'1': 1, '3': 1, '4': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======pemrograman internet=========
# pemrograman -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======algoritma & pemrograman ia=========
# algoritma -> 1
# pemrograman -> 1
# total keyword: 2
# {'1': 2}
# klasifikasi keahlian: 1
# ada
# done
# =======algoritma & pemrograman ib=========
# algoritma -> 1
# pemrograman -> 1
# total keyword: 2
# {'1': 2}
# klasifikasi keahlian: 1
# ada
# done
# =======algoritma & struktur data=========
# algoritma -> 1
# data -> 4
# struktur data -> 1
# total keyword: 3
# {'1': 2, '4': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======secure programming=========
# total keyword: 0
# {}
# done
# =======pengembanganaplikasi berbasisweb=========
# total keyword: 0
# {}
# done
# =======pengembanganaplikasi padaplatform kh=========
# total keyword: 0
# {}
# done
# =======pengembangan aplikasi piranti bergerak=========
# pengembangan aplikasi -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======algoritma dan struktur data=========
# algoritma -> 1
# data -> 4
# struktur data -> 1
# total keyword: 3
# {'1': 2, '4': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======pemodelan enterprise=========
# pemodelan -> 2
# enterprise -> 9
# total keyword: 2
# {'2': 1, '9': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======dasar-dasar pemrogramanrekayasa hayati=========
# total keyword: 0
# {}
# done
# =======dasar teknik elektro=========
# total keyword: 0
# {}
# done
# =======pengantar teknik komputer=========
# total keyword: 0
# {}
# done
# =======pengantar rangkaian elektrik=========
# rangkaian -> 10
# total keyword: 1
# {'10': 1}
# klasifikasi keahlian: 10
# ada
# done
# =======perencanaan tek. & sist. informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======sinyal dan sistem=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======rekayasa trafik & perancangan jar. multi=========
# total keyword: 0
# {}
# done
# =======kapita selekta teknik komputer=========
# total keyword: 0
# {}
# done
# =======etika profesi dan bisnis bidang komputer=========
# profesi -> 8
# total keyword: 1
# {'8': 1}
# klasifikasi keahlian: 8
# ada
# done
# =======manajemen inovasi=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======sistem keamanan komputer=========
# sistem -> 3
# sistem -> 4
# keamanan -> 4
# keamanan -> 8
# total keyword: 4
# {'3': 1, '4': 2, '8': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======jaringan komunikasi dan komputer=========
# jaringan -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======pengantar teknik elektro=========
# total keyword: 0
# {}
# done
# =======rekayasa traffik=========
# total keyword: 0
# {}
# done
# =======penelitian industri digital=========
# total keyword: 0
# {}
# done
# =======manajemen sumber daya manusia teknologi=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======organisasi teknologi informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======#na=========
# total keyword: 0
# {}
# done
# =======bisnis telekomunikasi=========
# total keyword: 0
# {}
# done
# =======analisa perancangan proses bisnis=========
# total keyword: 0
# {}
# done
# =======perencanaan sistem & teknologi informasi=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# total keyword: 3
# {'3': 1, '4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======pengantar ilmu ekonomi=========
# total keyword: 0
# {}
# done
# =======kendali sistem cerdas=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======manajemen perubahan=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======nilai resiko teknologi informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======layanan sistem dan teknologi informasi=========
# layanan -> 5
# sistem -> 3
# sistem -> 4
# informasi -> 4
# total keyword: 4
# {'5': 1, '3': 1, '4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======riset inovasi teknologi informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======jaringan informasi & sosial=========
# jaringan -> 3
# informasi -> 4
# sosial -> 8
# total keyword: 3
# {'3': 1, '4': 1, '8': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======perancangan layanan teknologi informas=========
# layanan -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======rekayasa sistem dan teknologi informasi=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# total keyword: 3
# {'3': 1, '4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======jaringan informasi dan sosial=========
# jaringan -> 3
# informasi -> 4
# sosial -> 8
# total keyword: 3
# {'3': 1, '4': 1, '8': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======rekayasa layanan teknologi informasi=========
# layanan -> 5
# informasi -> 4
# total keyword: 2
# {'5': 1, '4': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======sistem embedded waktu nyata=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======arsitektur & manajemen tek. informasi=========
# arsitektur -> 3
# manajemen -> 4
# informasi -> 4
# total keyword: 3
# {'3': 1, '4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======tatakelola dan audit teknologi informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======arsitektur manajemen teknologi informa=========
# arsitektur -> 3
# manajemen -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======manajemen kinerja & assurance teknologi=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======tatakelola & audit teknologi informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======sistem dan manajemen teknologi infor=========
# sistem -> 3
# sistem -> 4
# manajemen -> 4
# total keyword: 3
# {'3': 1, '4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======keprofesian sti=========
# keprofesian -> 8
# total keyword: 1
# {'8': 1}
# klasifikasi keahlian: 8
# ada
# done
# =======sistem layanan cerdas=========
# sistem -> 3
# sistem -> 4
# layanan -> 5
# total keyword: 3
# {'3': 1, '4': 1, '5': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======manajemen operasional layanan teknolog=========
# manajemen -> 4
# layanan -> 5
# total keyword: 2
# {'4': 1, '5': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======matematika teknik lanjut=========
# matematika -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======perilaku dinamis mesin elektrik=========
# mesin -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======elektronika daya lanjut=========
# total keyword: 0
# {}
# done
# =======sistem transportasi elektrik=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======hukum perlindungan anak=========
# total keyword: 0
# {}
# done
# =======bahasa indonesia hukum=========
# total keyword: 0
# {}
# done
# =======elektronika dayalanjut=========
# total keyword: 0
# {}
# done
# =======pengantar sistem tenaga elektrik=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======proyek perangkatlunak=========
# proyek -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======praktikum pengolahan sinyal digital=========
# total keyword: 0
# {}
# done
# =======perencanaan dan manajemen teknologi info=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======arsitektur sistem komputer=========
# arsitektur -> 3
# sistem -> 3
# sistem -> 4
# sistem komputer -> 3
# total keyword: 4
# {'3': 3, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======kerja mandiri i=========
# total keyword: 0
# {}
# done
# =======praktikum arsitektur sistem komputer=========
# arsitektur -> 3
# sistem -> 3
# sistem -> 4
# sistem komputer -> 3
# total keyword: 4
# {'3': 3, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======aplikasi inteligensi buatan=========
# total keyword: 0
# {}
# done
# =======tugas akhir i=========
# total keyword: 0
# {}
# done
# =======sistem informasi enterprise=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# enterprise -> 9
# sistem informasi -> 4
# sistem informasi enterprise -> 9
# total keyword: 6
# {'3': 1, '4': 3, '9': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======inteligensi buatan=========
# total keyword: 0
# {}
# done
# =======sistem berbasis pengetahuan=========
# sistem -> 3
# sistem -> 4
# pengetahuan -> 7
# total keyword: 3
# {'3': 1, '4': 1, '7': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem berbasispengetahuan=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======sistem informasienterprise=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======manajemen proyek perangkat lunak=========
# manajemen -> 4
# proyek -> 5
# manajemen proyek -> 5
# perangkat lunak -> 5
# proyek perangkat lunak -> 5
# total keyword: 5
# {'4': 1, '5': 4}
# klasifikasi keahlian: 5
# ada
# done
# =======sistem informasi=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======manajemen proyek sti=========
# manajemen -> 4
# proyek -> 5
# manajemen proyek -> 5
# total keyword: 3
# {'4': 1, '5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======representasipengetahuan danpenalaran=========
# total keyword: 0
# {}
# done
# =======socio-informatika dan profesionalisme=========
# socio-informatika dan profesionalisme -> 8
# total keyword: 1
# {'8': 1}
# klasifikasi keahlian: 8
# ada
# done
# =======socio-informatikadanprofesionalisme=========
# total keyword: 0
# {}
# done
# =======basis data non relasional=========
# data -> 4
# basis data -> 4
# total keyword: 2
# {'4': 2}
# klasifikasi keahlian: 4
# ada
# done
# =======manajemen basis data=========
# manajemen -> 4
# data -> 4
# basis data -> 4
# manajemen basis data -> 4
# total keyword: 4
# {'4': 4}
# klasifikasi keahlian: 4
# ada
# done
# =======strategi algoritmik=========
# total keyword: 0
# {}
# done
# =======strategi algoritma=========
# algoritma -> 1
# strategi algoritma -> 1
# total keyword: 2
# {'1': 2}
# klasifikasi keahlian: 1
# ada
# done
# =======keperawatan anak ii=========
# total keyword: 0
# {}
# done
# =======psikologi kesehatan=========
# total keyword: 0
# {}
# done
# =======topik khusus sainskomputer i=========
# total keyword: 0
# {}
# done
# =======analisis kebutuhan sistem=========
# analisis -> 2
# sistem -> 3
# sistem -> 4
# total keyword: 3
# {'2': 1, '3': 1, '4': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======pengantar teknologi informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======pengantar teknologi informasi dan algoritma=========
# informasi -> 4
# algoritma -> 1
# total keyword: 2
# {'4': 1, '1': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======multimedia database=========
# total keyword: 0
# {}
# done
# =======computer organizations=========
# total keyword: 0
# {}
# done
# =======introduction to it=========
# total keyword: 0
# {}
# done
# =======object oriented programming=========
# total keyword: 0
# {}
# done
# =======programing concept=========
# total keyword: 0
# {}
# done
# =======programming concept=========
# total keyword: 0
# {}
# done
# =======algoritma & pemrograman a=========
# algoritma -> 1
# pemrograman -> 1
# total keyword: 2
# {'1': 2}
# klasifikasi keahlian: 1
# ada
# done
# =======sistem temu balik informasi=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# temu balik -> 2
# total keyword: 4
# {'3': 1, '4': 2, '2': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======logika informatik=========
# logika -> 2
# logika -> 7
# total keyword: 2
# {'2': 1, '7': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======internship i=========
# total keyword: 0
# {}
# done
# =======image processing=========
# total keyword: 0
# {}
# done
# =======formal language automata=========
# automata -> 2
# automata -> 2
# automata -> 7
# total keyword: 3
# {'2': 2, '7': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======sistem informasi multimedia=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======artificial intelligence=========
# artificial intelligence -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======comparative programing language gui=========
# total keyword: 0
# {}
# done
# =======model simulasi=========
# simulasi -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======database design=========
# total keyword: 0
# {}
# done
# =======algorythmic strategies=========
# total keyword: 0
# {}
# done
# =======algorithmic strategies=========
# total keyword: 0
# {}
# done
# =======teknik kompilasi=========
# total keyword: 0
# {}
# done
# =======principles introduction to marketing=========
# total keyword: 0
# {}
# done
# =======it projject management=========
# management -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======business process analysis=========
# total keyword: 0
# {}
# done
# =======introduction to information technology=========
# total keyword: 0
# {}
# done
# =======programming concepts=========
# total keyword: 0
# {}
# done
# =======database system=========
# total keyword: 0
# {}
# done
# =======is project management=========
# project -> 5
# management -> 5
# total keyword: 2
# {'5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======engineering mathematics i=========
# total keyword: 0
# {}
# done
# =======introduction to it computing=========
# total keyword: 0
# {}
# done
# =======thesis=========
# total keyword: 0
# {}
# done
# =======product design development=========
# total keyword: 0
# {}
# done
# =======internship ii=========
# total keyword: 0
# {}
# done
# =======pengantar teknologi internet=========
# total keyword: 0
# {}
# done
# =======computer aided engineering=========
# total keyword: 0
# {}
# done
# =======information technology project manajemen=========
# project -> 5
# manajemen -> 4
# total keyword: 2
# {'5': 1, '4': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======sistem temu balikinformasi=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======logika informatika=========
# logika -> 2
# logika -> 7
# logika informatika -> 2
# logika informatika -> 7
# total keyword: 4
# {'2': 2, '7': 2}
# klasifikasi keahlian: 2
# ada
# done
# =======information system analysis design=========
# total keyword: 0
# {}
# done
# =======internet programming=========
# total keyword: 0
# {}
# done
# =======e-business=========
# total keyword: 0
# {}
# done
# =======matrix and vector=========
# total keyword: 0
# {}
# done
# =======paradigma pemrograman=========
# paradigma -> 1
# pemrograman -> 1
# total keyword: 2
# {'1': 2}
# klasifikasi keahlian: 1
# ada
# done
# =======kualitas data=========
# data -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======distributed system=========
# total keyword: 0
# {}
# done
# =======it project management=========
# project -> 5
# management -> 5
# total keyword: 2
# {'5': 2}
# klasifikasi keahlian: 5
# ada
# done
# =======data structure algorytms=========
# data -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======computer ethics=========
# total keyword: 0
# {}
# done
# =======physics ii=========
# total keyword: 0
# {}
# done
# =======distributed systems=========
# total keyword: 0
# {}
# done
# =======machine learning=========
# machine learning -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======algoritma  pemrograman a=========
# algoritma -> 1
# pemrograman -> 1
# total keyword: 2
# {'1': 4}
# ...
# total keyword: 1
# {'9': 1}
# klasifikasi keahlian: 9
# ada
# done
# =======manajemen rantai pasok dan hubungan pelanggan=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======tata tulis ilmiah=========
# total keyword: 0
# {}
# done
# =======jaringan komputer i=========
# jaringan -> 3
# jaringan komputer -> 3
# total keyword: 2
# {'3': 2}
# klasifikasi keahlian: 3
# ada
# done
# =======pengamanan jaringan=========
# jaringan -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======topik dlm mobile computing (komputasi be=========
# total keyword: 0
# {}
# done
# =======jar.nirkabel & komputasi bergerak=========
# total keyword: 0
# {}
# done
# =======prakt. sistem operasi=========
# sistem -> 3
# sistem -> 4
# sistem operasi -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======topik dalam pengamanan jaringan=========
# jaringan -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======topik khusus komputasi berbasis jaringan=========
# jaringan -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======topik dalam desain dan manajemen jaringa=========
# desain -> 5
# manajemen -> 4
# total keyword: 2
# {'5': 1, '4': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======topik dalam sistem operasi=========
# sistem -> 3
# sistem -> 4
# sistem operasi -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======topik khusus arsitektur dan jaringan komputer=========
# arsitektur -> 3
# jaringan -> 3
# jaringan komputer -> 3
# total keyword: 3
# {'3': 3}
# klasifikasi keahlian: 3
# ada
# done
# =======topik dalam komputasi awan=========
# awan -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======analisis perancangan kerja=========
# analisis -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======perencanaan tata letak pabrik=========
# total keyword: 0
# {}
# done
# =======analisa kelayakan pabrik=========
# total keyword: 0
# {}
# done
# =======industri kimia=========
# total keyword: 0
# {}
# done
# =======penelitian operasional i=========
# total keyword: 0
# {}
# done
# =======manajemen kwalitas=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======manajemen logistik=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======praktikum analisa perancangan=========
# total keyword: 0
# {}
# done
# =======ergonomi industrik=========
# total keyword: 0
# {}
# done
# =======pengendalian kwalitas statistik=========
# total keyword: 0
# {}
# done
# =======sistem produktifitas=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======pengetahuan bahan=========
# pengetahuan -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======elemen mesin=========
# mesin -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======manajemen kualitas proyek=========
# manajemen -> 4
# proyek -> 5
# total keyword: 2
# {'4': 1, '5': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======pengetahuan bisnis=========
# pengetahuan -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======pencegahan penang. kebakaran & bencana=========
# total keyword: 0
# {}
# done
# =======ergonomi perancangan kerja=========
# total keyword: 0
# {}
# done
# =======ergonomi & perancangan kerja=========
# total keyword: 0
# {}
# done
# =======audit perangkat lunak=========
# perangkat lunak -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======forensik digital=========
# total keyword: 0
# {}
# done
# =======animasi komputer dan pemodelan 3d=========
# pemodelan -> 2
# 3d -> 6
# total keyword: 2
# {'2': 1, '6': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======teori graf=========
# graf -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======algoritma dan pemrograman ii=========
# algoritma -> 1
# pemrograman -> 1
# total keyword: 2
# {'1': 2}
# klasifikasi keahlian: 1
# ada
# done
# =======hukum administrasi negara=========
# total keyword: 0
# {}
# done
# =======hukum bisnis=========
# total keyword: 0
# {}
# done
# =======hukum dan kebijakan publik=========
# total keyword: 0
# {}
# done
# =======topik dalam rekayasa sistem berbasis pengetahuan=========
# sistem -> 3
# sistem -> 4
# pengetahuan -> 7
# total keyword: 3
# {'3': 1, '4': 1, '7': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======rekayasa pengetahuan=========
# pengetahuan -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======sistem informasi perencanaan=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======topik dalam desain algoritma=========
# desain -> 5
# algoritma -> 1
# desain algoritma -> 1
# total keyword: 3
# {'5': 1, '1': 2}
# klasifikasi keahlian: 1
# ada
# done
# =======topik dalam bahasa pemrograman=========
# pemrograman -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======topik dalam penyempurnaan proses perangkat lunak=========
# perangkat lunak -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======penyempurnaan proses perangkat lunak=========
# perangkat lunak -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======sistem enterprise=========
# sistem -> 3
# sistem -> 4
# enterprise -> 9
# total keyword: 3
# {'3': 1, '4': 1, '9': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======pengantar ilmu lingkungan=========
# total keyword: 0
# {}
# done
# =======pra tugas akhir=========
# total keyword: 0
# {}
# done
# =======topik dalam desain dan audit jaringan=========
# desain -> 5
# jaringan -> 3
# total keyword: 2
# {'5': 1, '3': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======konstruksi perangkat lunak=========
# perangkat lunak -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======topik dalam portal korporat=========
# total keyword: 0
# {}
# done
# =======manaj.proyek perangkat lunak=========
# perangkat lunak -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======topik dalam tatakelola dan audit ti=========
# total keyword: 0
# {}
# done
# =======pola dan arsitektur perangkat lunak=========
# arsitektur -> 3
# perangkat lunak -> 5
# total keyword: 2
# {'3': 1, '5': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======topik dalam manajemen proyek perangkat lunak=========
# manajemen -> 4
# proyek -> 5
# manajemen proyek -> 5
# perangkat lunak -> 5
# proyek perangkat lunak -> 5
# total keyword: 5
# {'4': 1, '5': 4}
# klasifikasi keahlian: 5
# ada
# done
# =======audit sistem=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======topik khusus manajemen informasi=========
# manajemen -> 4
# informasi -> 4
# manajemen informasi -> 4
# total keyword: 3
# {'4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======topik dalam sistem informasi tanggap proses bisnis=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======komputasi client server=========
# total keyword: 0
# {}
# done
# =======komputasi awan=========
# awan -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======otomasi perkantoran=========
# total keyword: 0
# {}
# done
# =======sistem basis data ii=========
# sistem -> 3
# sistem -> 4
# data -> 4
# basis data -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======sistem operasi ii=========
# sistem -> 3
# sistem -> 4
# sistem operasi -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======data warehouse & olap*=========
# data -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======data mining*=========
# data -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======manajemen sains lanjut=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======topik dlm manaj.kualitas pl=========
# total keyword: 0
# {}
# done
# =======testing dan inplementasi sistem=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======topik dalam manajemen kualitas perangkat=========
# manajemen -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======topik dalam penjaminan kualitas perangkat lunak=========
# perangkat lunak -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======pola-pola perancangan=========
# total keyword: 0
# {}
# done
# =======prakt.pemrograman terstruktur=========
# total keyword: 0
# {}
# done
# =======organisasi arsitektur komputer=========
# arsitektur -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======topik khusus jaringan komputer=========
# jaringan -> 3
# jaringan komputer -> 3
# total keyword: 2
# {'3': 2}
# klasifikasi keahlian: 3
# ada
# done
# =======topik dalam jaringan nirkabel dan komput=========
# jaringan -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======komunikasi data=========
# data -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======topik dalam jaringan nirkabel=========
# jaringan -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======disertasi - seminar riset 2=========
# total keyword: 0
# {}
# done
# =======pneumatik/hidrolik i=========
# total keyword: 0
# {}
# done
# =======seminar skripsi=========
# total keyword: 0
# {}
# done
# =======praksistem operasi jaringan=========
# jaringan -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======prakteknik digital=========
# total keyword: 0
# {}
# done
# =======prakimple.basis data=========
# data -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======pneumatik dan hidrolik ii=========
# total keyword: 0
# {}
# done
# =======metdpenulisan ilmiah tek.presentasi=========
# total keyword: 0
# {}
# done
# =======kimia terapan i=========
# total keyword: 0
# {}
# done
# =======prakimplementasi struktur data=========
# data -> 4
# struktur data -> 1
# total keyword: 2
# {'4': 1, '1': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======prakgrafika komputer=========
# total keyword: 0
# {}
# done
# =======elemen mesin i=========
# mesin -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======mekanika fluida=========
# total keyword: 0
# {}
# done
# =======pengantar komputer=========
# total keyword: 0
# {}
# done
# =======interpersonal skill=========
# total keyword: 0
# {}
# done
# =======prakpemrograman c+dasar=========
# total keyword: 0
# {}
# done
# =======teknologi dan pemrogmobile=========
# total keyword: 0
# {}
# done
# =======topik dalam adopsi teknologi informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======kepemimpinan dan ketrampilan interpersonal=========
# total keyword: 0
# {}
# done
# =======otomata & pengantar kompilasi=========
# total keyword: 0
# {}
# done
# =======inteligensia mesin=========
# mesin -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======sistem operasi i=========
# sistem -> 3
# sistem -> 4
# sistem operasi -> 3
# total keyword: 3
# {'3': 2, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======desain & manajemen jaringan=========
# desain -> 5
# manajemen -> 4
# jaringan -> 3
# total keyword: 3
# {'5': 1, '4': 1, '3': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======jaringan nirkabel dan komputasi bergerak=========
# jaringan -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======komputasi pervasif dan jaringan sensor=========
# jaringan -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======jaringan nirkabel=========
# jaringan -> 3
# total keyword: 1
# {'3': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======topik dalam komputasi bergerak=========
# total keyword: 0
# {}
# done
# =======statistika dasar=========
# statistika -> 2
# statistika -> 7
# total keyword: 2
# {'2': 1, '7': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======matematika 2=========
# matematika -> 2
# total keyword: 1
# {'2': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======tek. penulisan buku sumber=========
# total keyword: 0
# {}
# done
# =======kebijakan pembangunan teknologi informas=========
# total keyword: 0
# {}
# done
# =======prakt. sistem digital=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======agama budha=========
# total keyword: 0
# {}
# done
# =======logika samar (fuzzy)=========
# logika -> 2
# logika -> 7
# total keyword: 2
# {'2': 1, '7': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======koding teori informasi=========
# informasi -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======kapita selekta logika fuzzi=========
# logika -> 2
# logika -> 7
# total keyword: 2
# {'2': 1, '7': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======sistem basis data tersebar=========
# sistem -> 3
# sistem -> 4
# data -> 4
# basis data -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======sistem informasi manajemen**=========
# sistem -> 3
# sistem -> 4
# informasi -> 4
# sistem informasi -> 4
# total keyword: 4
# {'3': 1, '4': 3}
# klasifikasi keahlian: 4
# ada
# done
# =======keamanan data dan informasi=========
# keamanan -> 4
# keamanan -> 8
# data -> 4
# informasi -> 4
# total keyword: 4
# {'4': 3, '8': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======testing dan implementasi si=========
# total keyword: 0
# {}
# done
# =======sistem intelijen berbasis agen=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======perilaku manusia dalam it=========
# total keyword: 0
# {}
# done
# =======sist.basisdata aplikasi basisdata web=========
# web -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======fraktal=========
# total keyword: 0
# {}
# done
# =======tugas khusus i=========
# total keyword: 0
# {}
# done
# =======metode penelitian lanjut=========
# total keyword: 0
# {}
# done
# =======fuzzy lanjut=========
# total keyword: 0
# {}
# done
# =======fuzzy logic=========
# total keyword: 0
# {}
# done
# =======distributed database=========
# total keyword: 0
# {}
# done
# =======konsep data spasial=========
# data -> 4
# total keyword: 1
# {'4': 1}
# klasifikasi keahlian: 4
# ada
# done
# =======disertasi 4=========
# total keyword: 0
# {}
# done
# =======konsep bahasa dan kompiler=========
# total keyword: 0
# {}
# done
# =======pemroaman lnajut 4=========
# total keyword: 0
# {}
# done
# =======motor bensin=========
# total keyword: 0
# {}
# done
# =======termodinamika=========
# total keyword: 0
# {}
# done
# =======praktikum mesin bensin=========
# mesin -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======termodinamika teknik=========
# total keyword: 0
# {}
# done
# =======intelligence agent system=========
# total keyword: 0
# {}
# done
# =======kecerdasan buatan dan model pemikiran=========
# kecerdasan buatan -> 7
# total keyword: 1
# {'7': 1}
# klasifikasi keahlian: 7
# ada
# done
# =======educational measurement=========
# total keyword: 0
# {}
# done
# =======ketidakpastian dalam sistem pakar=========
# sistem -> 3
# sistem -> 4
# total keyword: 2
# {'3': 1, '4': 1}
# klasifikasi keahlian: 3
# ada
# done
# =======teori compiler=========
# total keyword: 0
# {}
# done
# =======teori ketidakpastian=========
# total keyword: 0
# {}
# done
# =======dss lanjut=========
# total keyword: 0
# {}
# done
# =======komputasi simbolik=========
# total keyword: 0
# {}
# done
# =======information theory=========
# total keyword: 0
# {}
# done
# =======pemrograman=========
# pemrograman -> 1
# total keyword: 1
# {'1': 3}
# klasifikasi keahlian: 1
# ada
# done
# =======kecerdasan kelompok=========
# total keyword: 0
# {}
# done
# =======intelligence tutoring system=========
# total keyword: 0
# {}
# done
# =======labstatistik=========
# total keyword: 0
# {}
# done
# =======logika samar=========
# logika -> 2
# logika -> 7
# total keyword: 2
# {'2': 1, '7': 1}
# klasifikasi keahlian: 2
# ada
# done
# =======ketidakpastian=========
# total keyword: 0
# {}
# done
# =======proyek mahasiswa=========
# proyek -> 5
# total keyword: 1
# {'5': 1}
# klasifikasi keahlian: 5
# ada
# done
# =======advance e-commerce=========
# total keyword: 0
# {}
# done
# =======game develpoment=========
# game -> 6
# total keyword: 1
# {'6': 1}
# klasifikasi keahlian: 6
# ada
# done
# =======aplikasi berbasis web=========
# web -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======advanced interoperability=========
# total keyword: 0
# {}
# done
# =======game theory for wireless network=========
# game -> 6
# network -> 3
# total keyword: 2
# {'6': 1, '3': 1}
# klasifikasi keahlian: 6
# ada
# done
# =======kapita selekta e learning=========
# total keyword: 0
# {}
# done
# =======prakt. pemrograman berorientasi obyek=========
# pemrograman -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
# =======pengembangan aplikasi permainan=========
# pengembangan aplikasi -> 1
# total keyword: 1
# {'1': 1}
# klasifikasi keahlian: 1
# ada
# done
